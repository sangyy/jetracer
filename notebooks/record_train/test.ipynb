# %%
import uff
import tensorrt as trt
MODEL_DIR = 'model_tf/model.pb'
CHANNEL = 3
HEIGHT = 299
WIDTH = 299
ENGINE_PATH = './model_tf/model_.pb.plan'
INPUT_NODE = 'input'
OUTPUT_NODE = 'InceptionV3/Logits/SpatialSqueeze'
INPUT_SIZE = [CHANNEL, HEIGHT ,WIDTH] 
MAX_BATCH_SIZE = 1 
MAX_WORKSPACE = 1<<30


uff_model = uff.from_tensorflow_frozen_model(MODEL_DIR)
# Out:
# WARNING:tensorflow:From /usr/lib/python3.6/dist-packages/uff/converters/tensorflow/conversion_helpers.py:185: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# ---------------------------------------------------------------------------
# DecodeError                               Traceback (most recent call last)
# <ipython-input-4-083428ac9a97> in <module>
#      13
#      14
# ---> 15 uff_model = uff.from_tensorflow_frozen_model(MODEL_DIR)
#
# /usr/lib/python3.6/dist-packages/uff/converters/tensorflow/conversion_helpers.py in from_tensorflow_frozen_model(frozen_file, output_nodes, preprocessor, **kwargs)
#     184     graphdef = GraphDef()
#     185     with gfile.FastGFile(frozen_file, "rb") as frozen_pb:
# --> 186         graphdef.ParseFromString(frozen_pb.read())
#     187     return from_tensorflow(graphdef, output_nodes, preprocessor, **kwargs)
#
# ...

# %%
Wrong wire type in tag.
